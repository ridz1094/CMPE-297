# %% [markdown]
# Text Summarization

# %%
# !pip install -q gradio
# !pip install -q torch
# !pip install -q transformers
# !pip install -q sentencepiece
# !pip install -q bert-extractive-summarizer 
# !pip install -q protobuf
# Out:
#      |████████████████████████████████| 2.0 MB 5.2 MB/s
#      |████████████████████████████████| 1.9 MB 34.2 MB/s
#      |████████████████████████████████| 206 kB 28.5 MB/s
#      |████████████████████████████████| 63 kB 676 kB/s
#      |████████████████████████████████| 3.5 MB 42.7 MB/s
#      |████████████████████████████████| 961 kB 50.6 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for flask-cachebuster (setup.py) ... done
#      |████████████████████████████████| 3.1 MB 5.1 MB/s
#      |████████████████████████████████| 895 kB 46.9 MB/s
#      |████████████████████████████████| 596 kB 56.6 MB/s
#      |████████████████████████████████| 3.3 MB 47.5 MB/s
#      |████████████████████████████████| 56 kB 3.7 MB/s
#      |████████████████████████████████| 1.2 MB 5.3 MB/s

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM #Huggingface transformer
import torch

#For paraphrasing
from nltk.tokenize import sent_tokenize
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import nltk
nltk.download('punkt')
#For interface
import gradio as gr
from summarizer import Summarizer,TransformerSummarizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
bert_model = Summarizer()

# %%
def GenerateSummary(body):
  bert_summary = ''.join(bert_model(body, min_length=60))
  return bert_summary

# %%
iface = gr.Interface(
  fn=GenerateSummary, 
  inputs=["text"],    
  outputs=[gr.outputs.Textbox(label=" Paraphrased Summary ")],title= "Auto summarization"  )
iface.launch(debug=False)
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# This share link will expire in 72 hours. If you need a permanent link, visit: https://gradio.app/introducing-hosted
# Running on External URL: https://45878.gradio.app
#         <iframe
#             width="900"
#             height="500"
#             src="https://45878.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>,
#  'http://127.0.0.1:7864/',
#  'https://45878.gradio.app')
